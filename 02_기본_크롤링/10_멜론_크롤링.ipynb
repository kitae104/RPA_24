# %% [markdown]
# - chrome://version/

# %%
from bs4 import BeautifulSoup
import requests
import os

h = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36"}
response = requests.get("https://www.melon.com/chart/index.htm", headers=h)

html = response.text
soup = BeautifulSoup(html, 'html.parser')

singers = soup.select("span.checkEllipsis")
titles = soup.select(".ellipsis.rank01")
# images = soup.select("a.image_typeAll > img")

# 이미지 저장 폴더 생성
# image_folder = 'images'
# if not os.path.exists(image_folder):
#     os.makedirs(image_folder)

print(len(singers))
for i in range(len(singers)):
  singer = singers[i].get_text().strip()
  title = titles[i].get_text().strip()
  # img_url = images[i]['src']

  # 이미지 파일 이름 설정
  # image_filename = os.path.join(image_folder, f"{i + 1}_{singer}.jpg")

  # image_response = requests.get(img_url, headers=h)
  # with open(image_filename, 'wb') as f:
  #   f.write(image_response.content)

  print(f"{i+1}위 :  {title} / {singer} ")
# Out:
# 100
# 1위 :  녹아내려요 / DAY6 (데이식스)
# 2위 :  HAPPY / DAY6 (데이식스)
# 3위 :  Welcome to the Show / DAY6 (데이식스)
# 4위 :  WAY 4 LUV / PLAVE
# 5위 :  Pump Up The Volume! / PLAVE
# 6위 :  Supernova / aespa
# 7위 :  우리 영화 / PLAVE
# 8위 :  한 페이지가 될 수 있게 / DAY6 (데이식스)
# 9위 :  From / PLAVE
# 10위 :  사랑은 늘 도망가 / 임영웅
# 11위 :  Watch Me Woo! / PLAVE
# 12위 :  클락션 (Klaxon) / (여자)아이들
# 13위 :  여섯 번째 여름 / PLAVE
# 14위 :  How Sweet / NewJeans
# 15위 :  버추얼 아이돌 / PLAVE
# 16위 :  소나기 / 이클립스 (ECLIPSE)
# 17위 :  Sticky / KISS OF LIFE
# 18위 :  예뻤어 / DAY6 (데이식스)
# 19위 :  온기 / 임영웅
# 20위 :  우리들의 블루스 / 임영웅
# 21위 :  Home / 임영웅
# 22위 :  모래 알갱이 / 임영웅
# 23위 :  Small girl (feat. 도경수(D.O.)) / 이영지
# 24위 :  다시 만날 수 있을까 / 임영웅
# 25위 :  이제 나만 믿어요 / 임영웅
# 26위 :  Do or Die / 임영웅
# 27위 :  Supernatural / NewJeans
# 28위 :  Merry PLLIstmas / PLAVE
# 29위 :  무지개 / 임영웅
# 30위 :  London Boy / 임영웅
# 31위 :  Polaroid / 임영웅
# 32위 :  고민중독 / QWER
# 33위 :  Supersonic / 프로미스나인
# 34위 :  인생찬가 / 임영웅
# 35위 :  연애편지 / 임영웅
# 36위 :  Nice Guy / BOYNEXTDOOR
# ...
