# %%
from bs4 import BeautifulSoup
import requests
import os

h = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36"}
response = requests.get("https://www.melon.com/chart/index.htm", headers=h)

html = response.text
soup = BeautifulSoup(html, 'html.parser')

singers = soup.select("span.checkEllipsis")
titles = soup.select(".ellipsis.rank01")
images = soup.select("a.image_typeAll > img")

# 이미지 저장 폴더 생성
image_folder = 'images'
if not os.path.exists(image_folder):
    os.makedirs(image_folder)

print(len(singers))
for i in range(len(singers)):
  singer = singers[i].get_text().strip()
  title = titles[i].get_text().strip()
  img_url = images[i]['src']

  # 이미지 파일 이름 설정
  image_filename = os.path.join(image_folder, f"{i + 1}_{singer}.jpg")

  image_response = requests.get(img_url, headers=h)
  with open(image_filename, 'wb') as f:
    f.write(image_response.content)

  print(f"{i+1}위 :  {title} / {singer} ")
# Out:
# 100
# 1위 :  녹아내려요 / DAY6 (데이식스)
# 2위 :  Supernova / aespa
# 3위 :  클락션 (Klaxon) / (여자)아이들
# 4위 :  Welcome to the Show / DAY6 (데이식스)
# 5위 :  How Sweet / NewJeans
# 6위 :  한 페이지가 될 수 있게 / DAY6 (데이식스)
# 7위 :  Sticky / KISS OF LIFE
# 8위 :  소나기 / 이클립스 (ECLIPSE)
# 9위 :  HAPPY / DAY6 (데이식스)
# 10위 :  Small girl (feat. 도경수(D.O.)) / 이영지
# 11위 :  Supernatural / NewJeans
# 12위 :  고민중독 / QWER
# 13위 :  WAY 4 LUV / PLAVE
# 14위 :  예뻤어 / DAY6 (데이식스)
# 15위 :  나는 아픈 건 딱 질색이니까 / (여자)아이들
# 16위 :  Armageddon / aespa
# 17위 :  Pump Up The Volume! / PLAVE
# 18위 :  첫 만남은 계획대로 되지 않아 / TWS (투어스)
# 19위 :  Bubble Gum / NewJeans
# 20위 :  천상연 / 이창섭
# 21위 :  우리 영화 / PLAVE
# 22위 :  사랑은 늘 도망가 / 임영웅
# 23위 :  Magnetic / 아일릿(ILLIT)
# 24위 :  해야 (HEYA) / IVE (아이브)
# 25위 :  From / PLAVE
# 26위 :  Supersonic / 프로미스나인
# 27위 :  SPOT! (feat. JENNIE) / 지코 (ZICO)
# 28위 :  Watch Me Woo! / PLAVE
# 29위 :  Boom Boom Bass / RIIZE
# 30위 :  슬픈 초대장 / 순순희(지환)
# 31위 :  우리들의 블루스 / 임영웅
# 32위 :  에피소드 / 이무진
# 33위 :  버추얼 아이돌 / PLAVE
# 34위 :  Love wins all / 아이유
# 35위 :  온기 / 임영웅
# 36위 :  여섯 번째 여름 / PLAVE
# 37위 :  미안해 미워해 사랑해 / Crush
# 38위 :  비의 랩소디 / 임재현
# 39위 :  Home / 임영웅
# 40위 :  Hype Boy / NewJeans
# 41위 :  모래 알갱이 / 임영웅
# 42위 :  그녀가 웃었다 / DAY6 (데이식스)
# 43위 :  다시 만날 수 있을까 / 임영웅
# 44위 :  그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection)) / 너드커넥션 (Nerd Connection)
# 45위 :  내가 S면 넌 나의 N이 되어줘 / TWS (투어스)
# 46위 :  이제 나만 믿어요 / 임영웅
# 47위 :  헤어지자 말해요 / 박재정
# 48위 :  Seven (feat. Latto) - Clean Ver. / 정국
# 49위 :  I AM / IVE (아이브)
# 50위 :  별별별 (See that?) / NMIXX
# 51위 :  무지개 / 임영웅
# 52위 :  Do or Die / 임영웅
# 53위 :  London Boy / 임영웅
# 54위 :  너의 모든 순간 / 성시경
# 55위 :  To. X / 태연 (TAEYEON)
# 56위 :  Polaroid / 임영웅
# 57위 :  ETA / NewJeans
# 58위 :  Ditto / NewJeans
# 59위 :  다정히 내 이름을 부르면 / 경서예지, 전건호
# 60위 :  인생찬가 / 임영웅
# 61위 :  Merry PLLIstmas / PLAVE
# 62위 :  CRAZY / LE SSERAFIM (르세라핌)
# 63위 :  오래된 노래 / 허각, 임한별, 이무진, 이진성 (먼데이 키즈), 김희재, #안녕
# 64위 :  주저하는 연인들을 위해 / 잔나비
# 65위 :  Drama / aespa
# 66위 :  Attention / NewJeans
# 67위 :  사랑인가 봐 / 멜로망스
# 68위 :  괴물 / DAY6 (데이식스)
# 69위 :  Super Shy / NewJeans
# 70위 :  인사 / 범진
# 71위 :  연애편지 / 임영웅
# 72위 :  모든 날, 모든 순간 (Every day, Every Moment) / 폴킴
# 73위 :  사건의 지평선 / 윤하 (YOUNHA)
# 74위 :  Spicy / aespa
# 75위 :  망겜 / DAY6 (데이식스)
# 76위 :  어떻게 이별까지 사랑하겠어, 널 사랑하는 거지 / AKMU (악뮤)
# 77위 :  밤양갱 / 비비 (BIBI)
# 78위 :  청혼하지 않을 이유를 못 찾았어 / 이무진
# 79위 :  도와줘요 Rock&Roll / DAY6 (데이식스)
# 80위 :  아직 거기 살아 / DAY6 (데이식스)
# 81위 :  Love 119 / RIIZE
# 82위 :  파이팅 해야지 (Feat. 이영지) / 부석순 (SEVENTEEN)
# 83위 :  SHEESH / BABYMONSTER
# 84위 :  Get A Guitar / RIIZE
# 85위 :  Perfect Night / LE SSERAFIM (르세라핌)
# 86위 :  취중고백 / 김민석
# 87위 :  Dynamite / 방탄소년단
# 88위 :  사막에서 꽃을 피우듯 / 우디 (Woody)
# 89위 :  퀸카 (Queencard) / (여자)아이들
# 90위 :  I Don't Think That I Like Her / Charlie Puth
# 91위 :  LOVE DIVE / IVE (아이브)
# 92위 :  Girls Never Die / tripleS (트리플에스)
# 93위 :  COUNTER / DAY6 (데이식스)
# 94위 :  보금자리 / 임영웅
# 95위 :  봄날 / 방탄소년단
# 96위 :  꿈 / 태연 (TAEYEON)
# 97위 :  Live My Life / aespa
# 98위 :  Cosmic / Red Velvet (레드벨벳)
# 99위 :  I’m Fine / DAY6 (데이식스)
# 100위 :  Love Lee / AKMU (악뮤)
