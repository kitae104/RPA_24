# %% [markdown]
# 다음 > 영화 순위
#
# https://search.daum.net/search?w=tot&DA=YZR&t__nil_searchbox=btn&sug=&sugo=&sq=&o=&q=%EC%98%81%ED%99%94%EC%88%9C%EC%9C%84

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://search.daum.net/search?nil_suggest=btn&w=tot&DA=SBC&q=%EC%98%81%ED%99%94%EC%88%9C%EC%9C%84'

response = requests.get(url)

soup = BeautifulSoup(response.text, 'lxml')

movieInfoList = soup.find('ol', attrs={'class':'movie_list'}).find_all('li')

movieInfo = movieInfoList[0]

movieRank = movieInfo.find('span', attrs={'class':'num_rank01'}).get_text()
movieImg = movieInfo.find('img').attrs.get('src')
movieTitle = movieInfo.find('a', attrs={'class':'tit_main'}).get_text()
movieScore = movieInfo.find('em', attrs={'class':'rate'}).get_text()
movieScoreCnt = movieInfo.find('a', attrs={'class':'link_count'}).get_text()
movieTicketSales = movieInfo.find('dd', attrs={'class':'cont'}).get_text()
movieOpenDate = movieInfo.find_all('dd', attrs={'class':'cont'})[1].get_text().strip()

print(f'순위 : {movieRank}')
print(f'이미지 : {movieImg}')
print(f'제목 : {movieTitle}')
print(f'점수 : {movieScore}')
print(f'평가참여수 : {movieScoreCnt}')
print(f'예매율 : {movieTicketSales}')
print(f'개봉일자 : {movieOpenDate}')
# Out:
# 순위 : 1위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F8876ecefc861afc397a9943ab781bdf0316c4983
# 제목 : 슈퍼 마리오 브라더스
# 점수 : 9.2
# 평가참여수 : 24명 참여
# 예매율 : 24.6%
# 개봉일자 : 2023.04.26.

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://search.daum.net/search?nil_suggest=btn&w=tot&DA=SBC&q=%EC%98%81%ED%99%94%EC%88%9C%EC%9C%84'
headers = {
	'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36'
}

response = requests.get(url, headers=headers)

soup = BeautifulSoup(response.text, 'lxml')

# 리스트 정보 가져오기 
movieInfoList = soup.find('ol', attrs={'class':'movie_list'}).find_all('li')

for movieInfo in movieInfoList:
	movieRank = movieInfo.find('span', attrs={'class':f'img_number'})
	movieImg = movieInfo.find('img')
	movieTitle = movieInfo.find('a', attrs={'class':'tit_main'})
	movieScore = movieInfo.find('em', attrs={'class':'rate'})
	movieScoreCnt = movieInfo.find('a', attrs={'class':'link_count'})
	ticketSalesAndOpenDate = movieInfo.find_all('dd', attrs={'class':'cont'})
	if len(ticketSalesAndOpenDate) > 1:
		movieTicketSales = ticketSalesAndOpenDate[0]
		movieOpenDate = ticketSalesAndOpenDate[1]
	else: # 개봉일자가 없을 경우
		movieTicketSales = ticketSalesAndOpenDate[0]

	print(f'순위 : {movieRank.get_text() if movieRank else "X"}')
	print('이미지 : {}'.format(movieImg['src'] if movieImg else "X"))
	print(f'제목 : {movieTitle.get_text() if movieTitle else "X"}')
	print(f'점수 : {movieScore.get_text() if movieScore else "X"}')
	print(f'평가참여수 : {movieScoreCnt.get_text() if movieScoreCnt else "X"}')
	print(f'예매율 : {movieTicketSales.get_text() if movieTicketSales else "X"}')
	print(f'개봉일자 : {movieOpenDate.get_text().strip() if movieOpenDate else "X"}')
# Out:
# 순위 : 1위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F8876ecefc861afc397a9943ab781bdf0316c4983
# 제목 : 슈퍼 마리오 브라더스
# 점수 : 9.2
# 평가참여수 : 24명 참여
# 예매율 : 24.6%
# 개봉일자 : 2023.04.26.
# 순위 : 2위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F5605612b56736f1b4dedc8953b29b5d04c32c053
# 제목 : 존 윅 4
# 점수 : 8.0
# 평가참여수 : 262명 참여
# 예매율 : 19.9%
# 개봉일자 : 2023.04.12.
# 순위 : 3위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Feb514ac276500897a26a8e979b130571586021b5
# 제목 : 드림
# 점수 : 9.2
# 평가참여수 : 192명 참여
# 예매율 : 12.5%
# 개봉일자 : 2023.04.26.
# 순위 : 4위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F3a684ccaeb7aeac8e3f060ffe7249f7fe039443a
# 제목 : 스즈메의 문단속
# 점수 : 7.5
# 평가참여수 : 311명 참여
# 예매율 : 8.3%
# 개봉일자 : 2023.03.08.
# 순위 : 5위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Fa0aaca4b87c541b11085139bd941da0996a78ec1
# 제목 : 더 퍼스트 슬램덩크
# 점수 : 8.4
# 평가참여수 : 527명 참여
# 예매율 : 5.3%
# 개봉일자 : 2023.01.04.
# 순위 : 6위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Ffd6105e7d4919af308749f5785eee564320dfada
# 제목 : 옥수역귀신
# 점수 : 6.2
# 평가참여수 : 40명 참여
# 예매율 : 4.8%
# 개봉일자 : 2023.04.19.
# 순위 : 7위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F541382b0a4105163dc37e4aba7d44e8c115b72d6
# 제목 : 리바운드
# 점수 : 8.9
# 평가참여수 : 436명 참여
# 예매율 : 4.7%
# 개봉일자 : 2023.04.05.
# 순위 : 8위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Fbe239fd29a9a82847e419e4c0d0490a6ca8dd7e4
# 제목 : 킬링 로맨스
# 점수 : 5.8
# 평가참여수 : 151명 참여
# 예매율 : 3.6%
# 개봉일자 : 2023.04.14.
# 순위 : 9위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F85599d900af16c514f03e6257773304537ae529c
# 제목 : 렌필드
# 점수 : 7.8
# 평가참여수 : 22명 참여
# 예매율 : 2.7%
# 개봉일자 : 2023.04.19.
# 순위 : 10위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Fd2298754949746c6508d8aba2e9ef0f06141df61
# 제목 : 인셉션
# 점수 : 8.7
# 평가참여수 : 3,499명 참여
# 예매율 : 2.5%
# 개봉일자 : 2023.04.19.
# 순위 : 11위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Fa0887bce0ec55b149326221adf015579269570ea
# 제목 : 거울 속 외딴 성
# 점수 : 9.1
# 평가참여수 : 24명 참여
# 예매율 : 1.2%
# 개봉일자 : 2023.04.12.
# 순위 : 12위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F1e422202b9caca65297a0421972f576430374221
# 제목 : 라이스보이 슬립스
# 점수 : 9.1
# 평가참여수 : 18명 참여
# 예매율 : 1.2%
# 개봉일자 : 2023.04.19.
# 순위 : 13위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F2c81505312c588301e18b7f0a508bbc267ec2b44
# 제목 : 너의 이름은.
# 점수 : 7.9
# 평가참여수 : 2,274명 참여
# 예매율 : 0.6%
# 개봉일자 : 2021.09.09.
# 순위 : 14위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Fcee2dfa62bb078a3aaa4b6bd6b04c6330821a192
# 제목 : 아머드 사우루스: 기계공룡제국의 침략
# 점수 : 8.2
# 평가참여수 : 5명 참여
# 예매율 : 0.6%
# 개봉일자 : 2023.04.20.
# 순위 : 15위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F45d2757689eab926154349e73e0f68a9e273ed68
# 제목 : 65
# 점수 : 5.4
# 평가참여수 : 56명 참여
# 예매율 : 0.5%
# 개봉일자 : 2023.04.20.
# 순위 : 16위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F0e371de6f342a66143c49af3dd2b204342bbb5aa
# 제목 : 라라랜드
# 점수 : 8.1
# 평가참여수 : 2,232명 참여
# 예매율 : 0.4%
# 개봉일자 : 2020.12.31.
# 순위 : 17위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F87945a48498b2bd91b146821d68b660dec84226f
# 제목 : 멍뭉이
# 점수 : 6.5
# 평가참여수 : 106명 참여
# 예매율 : 0.4%
# 개봉일자 : 2023.03.01.
# 순위 : 18위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F0cdb0abb3d8da8c6332bf6a945a86f9a32f67abd
# 제목 : 아바타: 물의 길
# 점수 : 7.8
# 평가참여수 : 1,266명 참여
# 예매율 : 0.4%
# 개봉일자 : 2022.12.14.
# 순위 : 19위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F5db1885346421bd1ac13ead730d1b7b048a068ac
# 제목 : 귀를 기울이면
# 점수 : 10.0
# 평가참여수 : 3명 참여
# 예매율 : 0.3%
# 개봉일자 : 2023.04.19.
# 순위 : 20위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Fb0d552be0bd8b8b153cd480731ec76edcec7ace7
# 제목 : 콜드플레이 뮤직 오브 더 스피어스: 라이브 앳 리버 플레이트
# 점수 :
# 평가참여수 : X
# 예매율 : 0.3%
# 개봉일자 : 2023.04.19.
# 순위 : 21위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F6b3547d1b8ee29db7d2a3f6f78d35931bb2bbd2c
# 제목 : 날씨의 아이
# 점수 : 6.9
# 평가참여수 : 821명 참여
# 예매율 : 0.3%
# 개봉일자 : 2020.05.21.
# 순위 : 22위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Fd7dfd23fad7843cdfa228295b2e7536d0ce924f5
# 제목 : 카운트
# 점수 : 8.3
# 평가참여수 : 169명 참여
# 예매율 : 0.3%
# 개봉일자 : 2023.02.22.
# 순위 : 23위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F9e9706cd974c44109ca369ad36f177321573778897062
# 제목 : 초속5센티미터
# 점수 : 8.0
# 평가참여수 : 485명 참여
# 예매율 : 0.3%
# 개봉일자 : 2017.11.02.
# 순위 : 24위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F478632f46b2ed7a3c9088f785539f99426f5de9f
# 제목 : 레디 플레이어 원
# 점수 : 7.9
# 평가참여수 : 1,213명 참여
# 예매율 : 0.2%
# 개봉일자 : 2018.03.28.
# 순위 : 25위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Fcfile%2F2626C24D53CF28D609
# 제목 : 가디언즈 오브 갤럭시
# 점수 : 8.0
# 평가참여수 : 1,159명 참여
# 예매율 : 0.2%
# 개봉일자 : 2014.07.31.
# 순위 : 26위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F5f7b32312bf50ffdd7d6ec57523cf0e0d19f60a7
# 제목 : 가디언즈 오브 갤럭시 VOL. 2
# 점수 : 8.2
# 평가참여수 : 8,167명 참여
# 예매율 : 0.2%
# 개봉일자 : 2017.05.03.
# 순위 : 27위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F4c4d306467eec9a03e2dc09d432d6e6c2939933d
# 제목 : 오디션
# 점수 : 6.5
# 평가참여수 : 44명 참여
# 예매율 : 0.2%
# 개봉일자 : 2023.04.19.
# 순위 : 28위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Fc17bd488667977a165b768c837fc0e8e0cf0588d
# 제목 : 에어
# 점수 : 8.1
# 평가참여수 : 34명 참여
# 예매율 : 0.1%
# 개봉일자 : 2023.04.05.
# 순위 : 29위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F06e276d169a64256b73e55903d5d8df30c9bf554
# 제목 : 리턴 투 서울
# 점수 : 10.0
# 평가참여수 : 1명 참여
# 예매율 : 0.1%
# 개봉일자 : 2023.05.03.
# 순위 : 30위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Ffeb0710eb68b1e099ea6ba9db23def9961c8bb22
# 제목 : 클로즈
# 점수 : 6.5
# 평가참여수 : 12명 참여
# 예매율 : 0.1%
# 개봉일자 : 2023.05.03.

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://search.daum.net/search?nil_suggest=btn&w=tot&DA=SBC&q=%EC%98%81%ED%99%94%EC%88%9C%EC%9C%84'
headers = {
	'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36'
}

response = requests.get(url, headers=headers)

soup = BeautifulSoup(response.text, 'lxml')

movieInfoList = soup.find('ol', attrs={'class':'movie_list'}).find_all('li')

for movieInfo in movieInfoList:
	movieRank = movieInfo.find('span', attrs={'class':f'img_number'}).get_text()
	movieImg = movieInfo.find('img')['src']
	movieTitle = movieInfo.find('a', attrs={'class':'tit_main'}).get_text().replace(':', '')

	imgSrc = requests.get(movieImg, headers=headers)
	with open(f'{movieRank}-{movieTitle}.jfif', 'wb') as imgFile:
		imgFile.write(imgSrc.content)
