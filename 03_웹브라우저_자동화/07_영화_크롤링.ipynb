# %% [markdown]
# 다음 > 영화 순위
#
# https://search.daum.net/search?w=tot&DA=YZR&t__nil_searchbox=btn&sug=&sugo=&sq=&o=&q=%EC%98%81%ED%99%94%EC%88%9C%EC%9C%84

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://search.daum.net/search?nil_suggest=btn&w=tot&DA=SBC&q=%EC%98%81%ED%99%94%EC%88%9C%EC%9C%84'

response = requests.get(url)

soup = BeautifulSoup(response.text, 'lxml')

movieInfoList = soup.find('ol', attrs={'class':'movie_list'}).find_all('li')
print(len(movieInfoList))

movieInfo = movieInfoList[0]

movieRank = movieInfo.find('span', attrs={'class':'num_rank01'}).get_text()
movieImg = movieInfo.find('img').attrs.get('src')
movieTitle = movieInfo.find('a', attrs={'class':'tit_main'}).get_text()
movieScore = movieInfo.find('em', attrs={'class':'rate'}).get_text()
movieScoreCnt = movieInfo.find('a', attrs={'class':'link_count'}).get_text()
movieTicketSales = movieInfo.find('dd', attrs={'class':'cont'}).get_text()
movieOpenDate = movieInfo.find_all('dd', attrs={'class':'cont'})[1].get_text().strip()

print(f'순위 : {movieRank}')
print(f'이미지 : {movieImg}')
print(f'제목 : {movieTitle}')
print(f'점수 : {movieScore}')
print(f'평가참여수 : {movieScoreCnt}')
print(f'예매율 : {movieTicketSales}')
print(f'개봉일자 : {movieOpenDate}')
# Out:
# 29
# 순위 : 1위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Fe4ce2c6ae33edb0ef32d5614b367f85c10a7316c
# 제목 : 엘리멘탈
# 점수 : 8.6
# 평가참여수 : 96명 참여
# 예매율 : 33.2%
# 개봉일자 : 2023.06.14.

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://search.daum.net/search?nil_suggest=btn&w=tot&DA=SBC&q=%EC%98%81%ED%99%94%EC%88%9C%EC%9C%84'
headers = {
	'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36'
}

response = requests.get(url, headers=headers)

soup = BeautifulSoup(response.text, 'lxml')

# 리스트 정보 가져오기 
movieInfoList = soup.find('ol', attrs={'class':'movie_list'}).find_all('li')

for movieInfo in movieInfoList:
	movieRank = movieInfo.find('span', attrs={'class':f'img_number'})
	movieImg = movieInfo.find('img')
	movieTitle = movieInfo.find('a', attrs={'class':'tit_main'})
	movieScore = movieInfo.find('em', attrs={'class':'rate'})
	movieScoreCnt = movieInfo.find('a', attrs={'class':'link_count'})
	ticketSalesAndOpenDate = movieInfo.find_all('dd', attrs={'class':'cont'})
	if len(ticketSalesAndOpenDate) > 1:
		movieTicketSales = ticketSalesAndOpenDate[0]
		movieOpenDate = ticketSalesAndOpenDate[1]
	else: # 개봉일자가 없을 경우
		movieTicketSales = ticketSalesAndOpenDate[0]

	print(f'순위 : {movieRank.get_text() if movieRank else "X"}')
	print('이미지 : {}'.format(movieImg['src'] if movieImg else "X"))
	print(f'제목 : {movieTitle.get_text() if movieTitle else "X"}')
	print(f'점수 : {movieScore.get_text() if movieScore else "X"}')
	print(f'평가참여수 : {movieScoreCnt.get_text() if movieScoreCnt else "X"}')
	print(f'예매율 : {movieTicketSales.get_text() if movieTicketSales else "X"}')
	print(f'개봉일자 : {movieOpenDate.get_text().strip() if movieOpenDate else "X"}')
# Out:
# 순위 : 1위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Fe4ce2c6ae33edb0ef32d5614b367f85c10a7316c
# 제목 : 엘리멘탈
# 점수 : 8.6
# 평가참여수 : 93명 참여
# 예매율 : 29.2%
# 개봉일자 : 2023.06.14.
# 순위 : 2위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F1a9630c05575cb2b73eb29d62d96eb160f3e0444
# 제목 : 인디아나 존스: 운명의 다이얼
# 점수 : 8.8
# 평가참여수 : 72명 참여
# 예매율 : 20.6%
# 개봉일자 : 2023.06.28.
# 순위 : 3위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F1d3f11f50c660c43f4ba5c94ed3ef7a20c8c6cca
# 제목 : 스파이더맨: 어크로스 더 유니버스
# 점수 : 8.3
# 평가참여수 : 69명 참여
# 예매율 : 9.2%
# 개봉일자 : 2023.06.21.
# 순위 : 4위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Fb05fec37909f3c46d8ada73ba1d2bc2f8868e869
# 제목 : 범죄도시3
# 점수 : 6.6
# 평가참여수 : 1,087명 참여
# 예매율 : 8.7%
# 개봉일자 : 2023.05.31.
# 순위 : 5위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F945e8e4423929dff36c16293be23eb703dd7afa5
# 제목 : 귀공자
# 점수 : 8.1
# 평가참여수 : 377명 참여
# 예매율 : 7.4%
# 개봉일자 : 2023.06.21.
# 순위 : 6위
# 이미지 : https://search1.daumcdn.net/search/statics/common/pi/noimg/no_img_1x1.gif
# 제목 : 2022 영탁 단독 콘서트 "탁쇼"
# 점수 : 9.0
# 평가참여수 : 3명 참여
# 예매율 : 5.6%
# 개봉일자 : 2023.06.28.
# 순위 : 7위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F4782cfb079bd88055364a6ea3c7fd36bda9493c0
# 제목 : 여름날 우리
# 점수 : 7.9
# 평가참여수 : 43명 참여
# 예매율 : 2.8%
# 개봉일자 : 2023.06.28.
# 순위 : 8위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F69720ac488fc98d4171cf6c5769028a0e7c81a0b
# 제목 : 악마들
# 점수 : 8.8
# 평가참여수 : 12명 참여
# 예매율 : 2.4%
# 개봉일자 : 2023.07.05.
# 순위 : 9위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F64e400b5accb1ba88ad13adad4c8b3b962812a1a
# 제목 : 명탐정코난: 하이바라 아이 이야기 ~흑철의 미스터리 트레인
# 점수 : 8.9
# 평가참여수 : 8명 참여
# 예매율 : 2.1%
# 개봉일자 : 2023.06.23.
# 순위 : 10위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Fe17ef4b59bacef9887dd9faa3e4d2ffa8f937230
# 제목 : 애스터로이드 시티
# 점수 : 6.4
# 평가참여수 : 9명 참여
# 예매율 : 1.9%
# 개봉일자 : 2023.06.28.
# 순위 : 11위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Fc3fa110cbbe83eb6e4ae2b57124c84d28912f0fc
# 제목 : 극장판 도라에몽: 진구와 하늘의 유토피아
# 점수 : 10.0
# 평가참여수 : 1명 참여
# 예매율 : 1.2%
# 개봉일자 : 2023.07.08.
# 순위 : 12위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F132925ee1e42a7666cf8151cd558df1fd3dea5cf
# 제목 : 라방
# 점수 : 9.0
# 평가참여수 : 45명 참여
# 예매율 : 0.8%
# 개봉일자 : 2023.06.28.
# 순위 : 13위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F909a0f122378faeb5609a5a9f652130d7efb79c3
# 제목 : 파이어하트
# 점수 : 8.2
# 평가참여수 : 5명 참여
# 예매율 : 0.8%
# 개봉일자 : 2023.06.28.
# 순위 : 14위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F947a0d62f2772aa0f5c73b86b631779ef1183879
# 제목 : 플래시
# 점수 : 7.9
# 평가참여수 : 206명 참여
# 예매율 : 0.7%
# 개봉일자 : 2023.06.14.
# 순위 : 15위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F0792b57cc91a80cef6d4871e56a37393da1f9e6a
# 제목 : 수라
# 점수 : 9.8
# 평가참여수 : 65명 참여
# 예매율 : 0.5%
# 개봉일자 : 2023.06.21.
# 순위 : 16위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Fd9c60f9f3a9249adb6920ffe9dabd86b2a303a34
# 제목 : 샤이닝
# 점수 : 8.0
# 평가참여수 : 225명 참여
# 예매율 : 0.4%
# 개봉일자 : 2023.06.28.
# 순위 : 17위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F1a768adbada87d8776772ebdbfa4b40a7113ee9d
# 제목 : 보 이즈 어프레이드
# 점수 : 10.0
# 평가참여수 : 7명 참여
# 예매율 : 0.3%
# 개봉일자 : 2023.07.05.
# 순위 : 18위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Fa0aaca4b87c541b11085139bd941da0996a78ec1
# 제목 : 더 퍼스트 슬램덩크
# 점수 : 8.4
# 평가참여수 : 537명 참여
# 예매율 : 0.3%
# 개봉일자 : 2023.01.04.
# 순위 : 19위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Fecc18c94a03c9d245feac33da48160b2d53bf4e0
# 제목 : 엔니오: 더 마에스트로
# 점수 : 10.0
# 평가참여수 : 5명 참여
# 예매율 : 0.3%
# 개봉일자 : 2023.07.05.
# 순위 : 20위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F63efef6c4b381e1357395fe9ae00ff89da18c18d
# 제목 : 만해 한용운 님의침묵
# 점수 : 3.3
# 평가참여수 : 17명 참여
# 예매율 : 0.2%
# 개봉일자 : 2023.07.05.
# 순위 : 21위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Ff1b16bc494372fa515885a536e01a116b24e552f
# 제목 : 극장판 피노키오 위대한 모험
# 점수 : 10.0
# 평가참여수 : 19명 참여
# 예매율 : 0.2%
# 개봉일자 : 2023.07.13.
# 순위 : 22위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F3a684ccaeb7aeac8e3f060ffe7249f7fe039443a
# 제목 : 스즈메의 문단속
# 점수 : 7.3
# 평가참여수 : 384명 참여
# 예매율 : 0.2%
# 개봉일자 : 2023.03.08.
# 순위 : 23위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Ff3bb48813acf0cbc6bd9b988916455de3288f266
# 제목 : 하나님의 마음
# 점수 : 9.4
# 평가참여수 : 7명 참여
# 예매율 : 0.2%
# 개봉일자 : 2023.06.28.
# 순위 : 24위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F3ed58c2c1114935c4cc95f09949acb49b5996fa9
# 제목 : 미션 임파서블: 폴아웃
# 점수 : 8.1
# 평가참여수 : 1,623명 참여
# 예매율 : 0.2%
# 개봉일자 : 2018.07.25.
# 순위 : 25위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Fcfile%2F153E84105BBB18FB01
# 제목 : 매그놀리아
# 점수 : 8.2
# 평가참여수 : 81명 참여
# 예매율 : 0.2%
# 개봉일자 : 2000.04.15.
# 순위 : 27위
# 이미지 : https://search1.daumcdn.net/search/statics/common/pi/noimg/no_img_1x1.gif
# 제목 : 뮤지컬 윌리엄과 윌리엄의 윌리엄들
# 점수 :
# 평가참여수 : X
# 예매율 : 0.1%
# 개봉일자 : 2023.06.28.
# 순위 : 28위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2Ff05342a357e73804e73eaac0b2ac4fabf4c6ec7d
# 제목 : 플래닛
# 점수 : 8.1
# 평가참여수 : 12명 참여
# 예매율 : 0.1%
# 개봉일자 : 2023.07.05.
# 순위 : 29위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F69b2d6ef76c2c5b37b0641b187d1efd7f0636e41
# 제목 : 트랜스포머: 비스트의 서막
# 점수 : 7.2
# 평가참여수 : 141명 참여
# 예매율 : 0.1%
# 개봉일자 : 2023.06.06.
# 순위 : 30위
# 이미지 : https://search1.kakaocdn.net/thumb/R232x328.q85/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fmovie%2F6b0eb68a4c944965ae78c83112bbb799c25b876b
# 제목 : 가디언즈 오브 갤럭시: Volume 3
# 점수 : 8.7
# 평가참여수 : 437명 참여
# 예매율 : 0.1%
# 개봉일자 : 2023.05.03.

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://search.daum.net/search?nil_suggest=btn&w=tot&DA=SBC&q=%EC%98%81%ED%99%94%EC%88%9C%EC%9C%84'
headers = {
	'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36'
}

response = requests.get(url, headers=headers)

soup = BeautifulSoup(response.text, 'lxml')

movieInfoList = soup.find('ol', attrs={'class':'movie_list'}).find_all('li')

for movieInfo in movieInfoList:
	movieRank = movieInfo.find('span', attrs={'class':f'img_number'}).get_text()
	movieImg = movieInfo.find('img')['src']
	movieTitle = movieInfo.find('a', attrs={'class':'tit_main'}).get_text().replace(':', '')

	imgSrc = requests.get(movieImg, headers=headers)
	with open(f'{movieRank}-{movieTitle[:5]}.jfif', 'wb') as imgFile:
		imgFile.write(imgSrc.content)
