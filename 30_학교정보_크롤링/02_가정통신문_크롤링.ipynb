# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

# 로컬에 있는 chromedriver.exe 파일의 경로를 지정
chrome_driver_path = "chromedriver.exe"  # 본인의 실제 경로로 변경해주세요.

# 웹 드라이버 초기화
driver = webdriver.Chrome(executable_path=chrome_driver_path)

# 웹 사이트로 이동
driver.get("https://www.goeyi.kr/yongin-e/main.do")
time.sleep(1)

for i in range(1, 3):
  # id가 "notice1"인 요소 찾기   #container > div.MC_wrap1 > div > div.MC_box2.widgEdit > div > div.titTab > ul > li:nth-child(2)
  element = driver.find_element(By.CSS_SELECTOR, f"#container > div.MC_wrap1 > div > div.MC_box2.widgEdit > div > div.titTab > ul > li:nth-child({i})")
  element.click()

  notice_element = driver.find_element(By.CSS_SELECTOR, "#notice" + str(i))

  # 공지사항 리스트 가져오기
  notice_list = notice_element.find_elements(By.CSS_SELECTOR, f"#notice{i} > ul > li > a")

  for notice in notice_list:
    link = notice.get_attribute("href")
    print(notice.get_attribute("href"))

    driver.get(link)
    time.sleep(2)
    title = driver.find_element(By.CSS_SELECTOR, "#nttViewForm > div:nth-child(31) > h3").text
    print("제목:", title)
    content = driver.find_element(By.CSS_SELECTOR, "#nttViewForm > div:nth-child(32) > div.bbsV_cont").text 
    print("내용:", content)
    driver.back()
    print("-" * 50)
# Out:
# C:\Users\kitae\AppData\Local\Temp\ipykernel_11476\3321033531.py:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=chrome_driver_path)
# https://www.goeyi.kr/yongin-e/na/ntt/selectNttInfo.do?mi=11254&nttSn=1310251&bbsId=6361
# 제목: 유치원 입학원서 및 방과후과정 원서
# 내용:  -다운받은 입학원서는 아래 e-mail로 접수해 주세요~~
#  - 이메일 : tjdgpal17@ korea.kr(만3~4세), sookduk@korea.kr(만5세)
# --------------------------------------------------
# https://www.goeyi.kr/yongin-e/na/ntt/selectNttInfo.do?mi=11254&nttSn=1310242&bbsId=6361
# 제목: 2024학년도 유치원 유아 추가 모집(유치원이 새로운 환경에서 교육 활동을 시작합니다.)
# 내용: 1. 모집연령: 2019년생~ 2020년생 혼합연령1반, 2018년생 만5세1반  총 2반
#  2. 모집방법: e-mail 통한 접수 (학교홈페이지-알림마당-공지사항- 입학원서 다운 받은 후 e-mail 접수)
#  3. 입학문의: 031-8020-1300(교무실)- 유아명, 연락처를 남기시면 교사가 연락드립니다.
#      ※ 이메일 : tjdgpal17@ korea.kr(만3~4세), sookduk@korea.kr(만5세) :
#       ※    e-mail 접수 후031- 8020-1300, 031-8020-1350 으로 전화 요망
#
# 4. 용인초등학교병설유치원만의 장접 (2024학년도 새로운 환경에서 시작합니다.)
#    2024년 이런 점이 달라집니다.
# 내용
#   2024학년도부터 독립된 깨끗한 환경에서 교육활동을 시작합니다.
# 유치원이 학교 맨 앞쪽으로 이동하여 등, 하원이 더 용이합니다.
# 초등학교와 독립된 공간으로 외부인 출입이 어려워 더욱 안전합니다.
# 새롭게 조성된 놀이터에서 유아들이 맘껏 놀이할 수 있습니다.
# <병설유치원은 이런 점이 좋아요!!>
# ◦ 학부모 수익자 부담금이 없습니다. (2023학년도 기준)
# ◦ 만4세부터 놀이와 교재를 통한 기초 한글 지도로 자연스럽게 한글을 배울 수 있습니다.
# ◦ 방과후과정 운영 시 수익자 부담금이 없고, 전문교사를 활용하여 특성화 수업을 합니다.
# *위 내용은 2023학년도 기준입니다.
#  ◦ 방학기간은 교무실로 유아명, 부모 연락처를 남기시면 담당 교사가 직접 전화 연락드리겠습니다. (교무실 전화: 031-8020-1300), (유치원 대표전화: 031-8020-1350)
#
# * 자세한 사항은 추가모집공고파일을 확인하십시오.
#
# --------------------------------------------------
# https://www.goeyi.kr/yongin-e/na/ntt/selectNttInfo.do?mi=11254&nttSn=1309844&bbsId=6361
# 제목: 용인시 공립 초등학교 통학구역 확정 안내
# 내용: 2024학년도 용인시 공립 초등학교 통학구역이 확정되었다고 하오니 아래 붙임 자료를 참고하여 주시기 바랍니다.
# --------------------------------------------------
# https://www.goeyi.kr/yongin-e/na/ntt/selectNttInfo.do?mi=11254&nttSn=1308510&bbsId=6361
# 제목: 2023년 겨울철 교육시설 안전점검 결과 공개
# 내용: 2023년 겨울철 교육시설 안전점검 결과를 붙임과 같이 공개합니다.
# --------------------------------------------------
# https://www.goeyi.kr/yongin-e/na/ntt/selectNttInfo.do?mi=11254&nttSn=1308425&bbsId=6361
# 제목: 2023년 겨울방학 스쿨챌린지(기후행동 1.5℃ 앱) 참여
# 내용:
# --------------------------------------------------
# https://www.goeyi.kr/yongin-e/na/ntt/selectNttInfo.do?mi=11254&nttSn=1306913&bbsId=6361
# 제목: 양육자 대상 ‘디지털성범죄 예방 및 대응역량 강화 연수’ 안내
# 내용: 경기도교육청은 ‘경기도디지털성범죄피해자원스톱지원센터’와의 업무협약 체결을 통해
# 도내 학생의 디지털성범죄를 예방하고 피해 학생의 회복과 지원을 위해 노력하고 있습니다.
# 디지털성범죄 예방 사업의 일환으로, ‘경기도디지털성범죄피해자원스톱지원센터’와 연계하여
# 「양육자 대상 디지털성범죄 예방 및 대응역량 강화 연수」를 진행하오니,
# 관심있는 양육자(학부모, 조부모 등 아동･청소년을 양육하고 있는 누구나 참여 가능)는
# 다음 내용을 참고하여 연수에 신청해주시기 바랍니다.
#   1. 연 수 명 : 양육자 대상 ‘디지털성범죄 예방 및 대응역량 강화 연수’
# 2. 연수주제 : 양육자가 알아야 할 디지털네이티브 세대 특성과 디지털성범죄 예방
# 3. 신청대상 : 아동･청소년을 양육하고 있는 경기도 내 양육자
# 4. 신청기간 : 2023.12.4.(월) ~ 12.10.(일)
#   5. 모집인원 : 총 300명 (회차당 100명 내외)
#  6. 연수개요
# 연수일정
# 모집인원
# 연수방법
# 연수기관
# 1회차
# 2023. 12. 12.(화) 10:00~12:00(2시간)
# 100명
#  비대면
# 실시간
# 화상연수
# (ZOOM)
#  ※참여링크는
# 연수신청기간 종료후 개별발송 예정
# 경기도
# 디지털
# 성범죄
# 피해자
# 원스톱
# 지원센터
# 2회차
# 2023. 12. 14.(목) 10:00~12:00(2시간)
# 100명
# 3회차
# 2023. 12. 18.(월) 10:00~12:00(2시간)
# 100명
#    7. 신청방법: 홍보자료의 QR코드 또는 링크(https://forms.gle/2DDcJcrBDquwJHGa7) 접속 후,
# 구글 신청서 작성 및 제출
# --------------------------------------------------
# https://www.goeyi.kr/yongin-e/na/ntt/selectNttInfo.do?mi=11316&nttSn=1262565&bbsId=6406
# 제목: 2023 방과후학교 2분기 가정통신문
# 내용:
# --------------------------------------------------
# https://www.goeyi.kr/yongin-e/na/ntt/selectNttInfo.do?mi=11316&nttSn=1246767&bbsId=6406
# 제목: 학교 교육활동 보호 안내
# 내용:
# --------------------------------------------------
# https://www.goeyi.kr/yongin-e/na/ntt/selectNttInfo.do?mi=11316&nttSn=1207606&bbsId=6406
# 제목: 2023학년도 방과후학교 1분기 모집 안내 가정통신문
# 내용: 상세 내용은 붙임파일과 이알리미 가정통신문을 참고해주세요
#
#
# --------------------------------------------------
# https://www.goeyi.kr/yongin-e/na/ntt/selectNttInfo.do?mi=11316&nttSn=359303&bbsId=6406
# 제목: 12월 용인급식통신
# 내용:
# --------------------------------------------------
# https://www.goeyi.kr/yongin-e/na/ntt/selectNttInfo.do?mi=11316&nttSn=359302&bbsId=6406
# 제목: 2022년도 제3차 아동학대 예방 공익광고
# 내용: 2022년도 제3차 아동학대 예방 공익광고 영상
#
# https://www.youtube.com/watch?v=Zsv4q6xF7uM
#
# 위에 링크를 클릭하세요!
#
# 사랑의 손을 함께 들어주세요!
# --------------------------------------------------
# https://www.goeyi.kr/yongin-e/na/ntt/selectNttInfo.do?mi=11316&nttSn=359301&bbsId=6406
# 제목: 11월 용인급식통신
# 내용:
# --------------------------------------------------
